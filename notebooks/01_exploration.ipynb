# %%
import pandas as pd 
import kaggle 
from dotenv import load_dotenv

import os

# %%
# Load dotenv
load_dotenv()

# Import environment variables
KAGGLE_TOKEN_NAME = os.environ['KAGGLE_TOKEN_NAME']
KAGGLE_TOKE_VALUE = os.environ['KAGGLE_TOKEN_VALUE']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 6
#       4 # Import environment variables
#       5 KAGGLE_TOKEN_NAME = os.environ['KAGGLE_TOKEN_NAME']
# ----> 6 KAGGLE_TOKE_VALUE = os.environ['KAGGLE_TOKEN_VALUE']
#
# File <frozen os>:679, in __getitem__(self, key)
#
# KeyError: 'KAGGLE_TOKEN_VALUE'
